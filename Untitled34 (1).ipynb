# %%
# IMporting the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import matplotlib.colors as mcolors
import warnings
warnings.filterwarnings("ignore")

# %%
#Dta collection
#Read Dataset  
data=pd.read_csv('C:\\Users\\HP\\Desktop\\training_HR.csv')
data_test=pd.read_csv('C:\\Users\\HP\\Desktop\\test_HR.csv')
print(data.head())
print(data.shape)
print(data_test.shape)
data_test.isna().sum()
data_t1=data_test
print(data_t1.shape)
l1=[]
l1=data_test['employee_id']
print(l1)
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# ...

# %%
print(data_test.shape)
for i in data.columns:
    print(str(data[i])+str(data[i].value_counts()))
    
data.isna().sum()
data['education'].value_counts()
data['education'].fillna("Bachelor's", inplace=True)
data.isna().sum()
data['previous_year_rating'].value_counts()
data.previous_year_rating.fillna(method="ffill", inplace=True)
data.isna().sum()
data.describe()
data_test['education'].value_counts()
data_test['education'].fillna("Bachelor's", inplace=True)
print(data_test.columns)
data_test.isna().sum()
data_test['previous_year_rating'].value_counts()
data_test.previous_year_rating.fillna(method="ffill", inplace=True)
data_test.isna().sum()
data_test.describe()
print(data_test.shape)
# Out:
# (23490, 13)
# 0        65438
# 1        65141
# 2         7513
# 3         2542
# 4        48945
#          ...
# 54803     3030
# 54804    74592
# 54805    13918
# 54806    13614
# 54807    51526
# Name: employee_id, Length: 54808, dtype: int6465438    1
# 16223    1
# 38250    1
# 68086    1
# 78080    1
#         ..
# 38645    1
# 76563    1
# 46788    1
# 75029    1
# 51526    1
# Name: employee_id, Length: 54808, dtype: int64
# 0        Sales & Marketing
# 1               Operations
# 2        Sales & Marketing
# 3        Sales & Marketing
# 4               Technology
#                ...
# 54803           Technology
# 54804           Operations
# 54805            Analytics
# 54806    Sales & Marketing
# 54807                   HR
# Name: department, Length: 54808, dtype: objectSales & Marketing    16840
# Operations           11348
# Technology            7138
# Procurement           7138
# Analytics             5352
# Finance               2536
# HR                    2418
# ...

# %%
print(data_test.isna().sum())
data_test.previous_year_rating.fillna(method="bfill", inplace=True)
print(data_test.isna().sum())

print(data_test.shape)
# Out:
# employee_id             0
# department              0
# region                  0
# education               0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# previous_year_rating    1
# length_of_service       0
# KPIs_met >80%           0
# awards_won?             0
# avg_training_score      0
# dtype: int64
# employee_id             0
# department              0
# region                  0
# education               0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# previous_year_rating    0
# length_of_service       0
# KPIs_met >80%           0
# awards_won?             0
# avg_training_score      0
# dtype: int64
# (23490, 13)

# %%
print(data.head())
print(data_test.head())
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# ...

# %%
print(data_test.shape)
#Encoding
from sklearn.preprocessing import LabelEncoder
label_en=LabelEncoder()
a=['department']
for i in np.arange(len(a)):
    data[a[i]]=label_en.fit_transform(data[a[i]])

a=['region']
for i in np.arange(len(a)):
    data[a[i]]=label_en.fit_transform(data[a[i]])
a=['education']
for i in np.arange(len(a)):
    data[a[i]]=label_en.fit_transform(data[a[i]])
# One hot encoding
data = pd.get_dummies(data, columns = ['gender','recruitment_channel'],drop_first=True)
data.head()

print(data_test.shape)
label_en=LabelEncoder()
a=['department']
for i in np.arange(len(a)):
    data_test[a[i]]=label_en.fit_transform(data_test[a[i]])

a=['region']
for i in np.arange(len(a)):
    data_test[a[i]]=label_en.fit_transform(data_test[a[i]])
a=['education']
for i in np.arange(len(a)):
    data_test[a[i]]=label_en.fit_transform(data_test[a[i]])
# One hot encoding
data_test = pd.get_dummies(data_test, columns = ['gender','recruitment_channel'],drop_first=True)
print(data_test.shape)
# Out:
# (23490, 13)
# (23490, 13)
# (23490, 14)

# %%
data['KPI']=data['KPIs_met >80%']
data['awards']=data['awards_won?']
data['gender']=data['gender_m']

data['recruitment_channel']=data['recruitment_channel_referred']
data['channel_sourcing']=data['recruitment_channel_sourcing']
data.drop(['KPIs_met >80%','awards_won?','gender_m','recruitment_channel_referred','recruitment_channel_sourcing'],axis=1,inplace=True)
data.head()

data_test['KPI']=data_test['KPIs_met >80%']
data_test['awards']=data_test['awards_won?']
data_test['gender']=data_test['gender_m']

data_test['recruitment_channel']=data_test['recruitment_channel_referred']
data_test['channel_sourcing']=data_test['recruitment_channel_sourcing']
data_test.drop(['KPIs_met >80%','awards_won?','gender_m','recruitment_channel_referred','recruitment_channel_sourcing'],axis=1,inplace=True)
data_test.head()
print(data_test.shape)
# Out:
# (23490, 14)

# %%
data['KPI'].unique()
data['KPI'].value_counts()
data.columns
data['awards'].unique()
data['awards'].value_counts()

data_test['KPI'].unique()
data_test['KPI'].value_counts()
data_test.columns
data_test['awards'].unique()
data_test['awards'].value_counts()
print(data_test.shape)
# Out:
# (23490, 14)

# %%
# Checking outliers in the column 'age'
plt.boxplot(data['age'])
plt.title("age")
plt.show()
# Handling outliers in the column 'age'
Q1=np.percentile(data['age'],25,interpolation='midpoint')
Q2=np.percentile(data['age'],50,interpolation='midpoint')
Q3=np.percentile(data['age'],75,interpolation='midpoint')
IQR = Q3 - Q1
lowlim=Q1=1.5*IQR
uplim=Q3+1.5*IQR
print(lowlim)
print(uplim)
outlier = []
for x in data['age']:
    if ((x>uplim) or (x<lowlim)):
        outlier.append(x)
ind1=data['age']>uplim
y=data.loc[ind1].index

data.drop(y,inplace = True)
plt.boxplot(data['age'])
plt.title("age")
plt.show()
print(data_test.shape)
# Out:
# 15.0
# 54.0
# (23490, 14)

# %%
# Checking outliers in the column 'region'
plt.boxplot(data['region'])
plt.title("region")
plt.show()
plt.boxplot(data_test['region'])
plt.title("region")
plt.show()

# %%
plt.boxplot(data['previous_year_rating'])
plt.title("previous_year_rating")
plt.show()
plt.boxplot(data_test['previous_year_rating'])
plt.title("previous_year_rating")
plt.show()

# %%
print(data_test.shape)
# Checking outliers in the column 'region'
plt.boxplot(data['length_of_service'])
plt.title("length_of_service")
plt.show()

Q1=np.percentile(data['length_of_service'],25,interpolation='midpoint')
Q2=np.percentile(data['length_of_service'],50,interpolation='midpoint')
Q3=np.percentile(data['length_of_service'],75,interpolation='midpoint')
IQR = Q3 - Q1
lowlim=Q1=1.5*IQR
uplim=Q3+1.5*IQR
print(lowlim)
print(uplim)
outlier = []
for x in data['length_of_service']:
    if ((x>uplim) or (x<lowlim)):
        outlier.append(x)
ind1=data['length_of_service']>uplim
y=data.loc[ind1].index

data.drop(y,inplace = True)
plt.boxplot(data['length_of_service'])
plt.title("length_of_service")
plt.show()
# Out:
# (23490, 14)
# 6.0
# 13.0

# %%
plt.boxplot(data['avg_training_score'])
plt.title("avg_training_score")
plt.show()
plt.boxplot(data_test['avg_training_score'])
plt.title("avg_training_score")
plt.show()

# %%
print(data.head())
print(data_test.shape)
# Out:
#    employee_id  department  region  education  no_of_trainings  age  \
# 0        65438           7      31          2                1   35
# 1        65141           4      14          0                1   30
# 2         7513           7      10          0                1   34
# 3         2542           7      15          0                2   39
# 4        48945           8      18          0                1   45
#
#    previous_year_rating  length_of_service  avg_training_score  is_promoted  \
# 0                   5.0                  8                  49            0
# 1                   5.0                  4                  60            0
# 2                   3.0                  7                  50            0
# 3                   1.0                 10                  50            0
# 4                   3.0                  2                  73            0
#
#    KPI  awards  gender  recruitment_channel  channel_sourcing
# ...

# %%
y=data['is_promoted']
#x=data.drop(['employee_id','is_promoted'],axis=1)
x=data.drop(['is_promoted'],axis=1)
#Standardization/Normalization
from sklearn import preprocessing
min_max=preprocessing.MinMaxScaler(feature_range=(0,1))
x=min_max.fit_transform(x)
x=pd.DataFrame(x)
x.describe()
# Out:
#                  0             1             2             3             4   \
# count  50590.000000  50590.000000  50590.000000  50590.000000  50590.000000
# mean       0.500418      0.617531      0.471563      0.261208      0.028914
# std        0.288363      0.316530      0.267889      0.434746      0.068317
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.251494      0.500000      0.333333      0.000000      0.000000
# 50%        0.500140      0.625000      0.424242      0.000000      0.000000
# 75%        0.750077      0.875000      0.666667      1.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                  5             6             7             8             9   \
# count  50590.000000  50590.000000  50590.000000  50590.000000  50590.000000
# mean       0.396816      0.582912      0.336279      0.408278      0.359577
# ...

# %%
print(data_test.shape)
#x_test=data_test.drop(['employee_id'],axis=1)
x_test=data_test.iloc[:]
#Standardization/Normalization
from sklearn import preprocessing
min_max_test=preprocessing.MinMaxScaler(feature_range=(0,1))
x_test=min_max_test.fit_transform(x_test)
x_test=pd.DataFrame(x_test)
x_test.describe()
# Out:
# (23490, 14)
#                  0             1             2             3             4   \
# count  23490.000000  23490.000000  23490.000000  23490.000000  23490.000000
# mean       0.498626      0.620929      0.468651      0.284845      0.031779
# std        0.289184      0.314312      0.264400      0.446919      0.075114
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.247372      0.500000      0.333333      0.000000      0.000000
# 50%        0.497631      0.625000      0.424242      0.000000      0.000000
# 75%        0.749591      0.875000      0.636364      1.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                  5             6             7             8             9   \
# count  23490.000000  23490.000000  23490.000000  23490.000000  23490.000000
# mean       0.369573      0.584568      0.145769      0.404386      0.358834
# ...

# %%
plt.figure(figsize=(10,10))
for i in data.columns:
    sns.scatterplot(data[i],data['is_promoted'])
    plt.show()

# %%
plt.figure(figsize=(25,10))
ax = sns.heatmap(data.corr(), annot=True)

# %%
#print(data_test.columns)
print(data_test.shape)

data = data[['department', 'region', 'education', 'gender','age','no_of_trainings','previous_year_rating','length_of_service','avg_training_score','KPI','awards','recruitment_channel','channel_sourcing','is_promoted']]
print(data.head())

data_test = data_test[['department', 'region', 'education', 'gender','age','no_of_trainings','previous_year_rating','length_of_service','avg_training_score','KPI','awards','recruitment_channel','channel_sourcing']]
print(data_test.shape)
print(data.columns)
# Out:
# (23490, 14)
#    department  region  education  gender  age  no_of_trainings  \
# 0           7      31          2       0   35                1
# 1           4      14          0       1   30                1
# 2           7      10          0       1   34                1
# 3           7      15          0       1   39                2
# 4           8      18          0       1   45                1
#
#    previous_year_rating  length_of_service  avg_training_score  KPI  awards  \
# 0                   5.0                  8                  49    1       0
# 1                   5.0                  4                  60    0       0
# 2                   3.0                  7                  50    0       0
# 3                   1.0                 10                  50    0       0
# 4                   3.0                  2                  73    0       0
#
#    recruitment_channel  channel_sourcing  is_promoted
# 0                    0                 1            0
# ...

# %%
y=data.iloc[:,13:14]
x=data.iloc[:,0:13]
print(x)
print(y)
# Out:
#        department  region  education  gender  age  no_of_trainings  \
# 0               7      31          2       0   35                1
# 1               4      14          0       1   30                1
# 2               7      10          0       1   34                1
# 3               7      15          0       1   39                2
# 4               8      18          0       1   45                1
# ...           ...     ...        ...     ...  ...              ...
# 54802           7       5          0       1   31                2
# 54804           4      19          2       0   37                1
# 54805           0       0          0       1   27                1
# 54806           7      33          0       1   29                1
# 54807           2      14          0       1   27                1
#
#        previous_year_rating  length_of_service  avg_training_score  KPI  \
# 0                       5.0                  8                  49    1
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=42)

# %%
print(x_test.shape)
#print(y_test.shape)
#print(x_train.shape)
#print(y_train.shape)
print(data_test.shape)
# Out:
# (20236, 13)
# (23490, 13)

# %%
# Model 2 : Decision Tree Model

from sklearn.tree import DecisionTreeClassifier
dt_model=DecisionTreeClassifier()
dt_model.fit(x_train,y_train)
dt_model.fit(x,y)

y_pred=dt_model.predict(x_test)

from sklearn.metrics import f1_score

print('F1_score :',f1_score(y_pred, y_test,average='micro'))
# Out:
# F1_score : 0.9997529155959676

# %%
print(data_test.isna().sum())
data_test.previous_year_rating.fillna(method="ffill",inplace=True)
print(data_test.isna().sum())
print(data_test.shape)
# Out:
# department              0
# region                  0
# education               0
# gender                  0
# age                     0
# no_of_trainings         0
# previous_year_rating    0
# length_of_service       0
# avg_training_score      0
# KPI                     0
# awards                  0
# recruitment_channel     0
# channel_sourcing        0
# dtype: int64
# department              0
# region                  0
# education               0
# gender                  0
# age                     0
# no_of_trainings         0
# previous_year_rating    0
# length_of_service       0
# avg_training_score      0
# KPI                     0
# awards                  0
# recruitment_channel     0
# channel_sourcing        0
# dtype: int64
# (23490, 13)

# %%
x_test=data_test.iloc[:,0:14]
x_test.values.reshape(23490,13)
print(x_test.shape)

y_pred=dt_model.predict(x_test)
data_sub=pd.DataFrame()
data_sub['employee_id']=l1
#data_sub['employee_id']=data_test['employee_id']
data_sub['is_promoted']=y_pred
#print(data_t1.columns)


data_sub.to_csv('C:\\Users\\HP\\Desktop\\output.csv',index=False)

print(y_pred.shape)
# Out:
# (23490, 13)
# (23490,)
